# %%
import pandas as pd

# Load raw data
matches = pd.read_csv('../data/raw/matches.csv')
players = pd.read_csv('../data/raw/player_stats.csv')

# Overview
print(matches.head())
print(matches.info())
print(matches.describe())

# Null check
print(matches.isnull().sum())

# Unique teams & stadiums
print(matches['team1'].unique())
print(matches['venue'].unique())
