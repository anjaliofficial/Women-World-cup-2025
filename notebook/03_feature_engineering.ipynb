# %%
import pandas as pd

players = pd.read_csv('../data/raw/player_stats.csv')

# Create Strike Rate & Economy Rate
players['strike_rate'] = (players['runs'] / players['balls_faced']) * 100
players['economy_rate'] = players['runs_conceded'] / (players['overs_bowled'])

# Save new processed data
players.to_csv('../data/processed/player_stats.csv', index=False)
print("✅ Feature Engineering Done")
